# %%
import os

# %%
# %pwd
# Out:
# 'd:\\Projects\\End-to-End-DL-Project---Brain-MRI-Tumour-Classification\\research'

# %%
os.chdir("../")

# %%
# %pwd
# Out:
# 'd:\\Projects\\End-to-End-DL-Project---Brain-MRI-Tumour-Classification'
